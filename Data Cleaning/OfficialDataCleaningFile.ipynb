# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATASETS
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S R
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

DATASET_MAPPING = 'eurusdforextradingindicatornotcleaned:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F951209%2F1611238%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20201102%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20201102T053415Z%26X-Goog-Expires%3D259199%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'
KAGGLE_INPUT_PATH = '/home/kaggle/input'
KAGGLE_INPUT_SYMLINK = '/kaggle'

system(paste0('sudo mkdir -p -- ', KAGGLE_INPUT_PATH), intern=TRUE)
system(paste0('sudo chmod 777 ', KAGGLE_INPUT_PATH), intern=TRUE)
system(paste0('sudo ln -sfn ', KAGGLE_INPUT_PATH, ' ../'), intern=TRUE)
system(paste0('sudo mkdir -p -- ', KAGGLE_INPUT_SYMLINK))
system(paste0('sudo ln -sfn ', KAGGLE_INPUT_PATH, ' ', KAGGLE_INPUT_SYMLINK))

datasets_mappings = strsplit(DATASET_MAPPING, ',')[[1]]
for (dataset_mapping in datasets_mappings) {
    path_and_url = strsplit(dataset_mapping, ':')
    directory = path_and_url[[1]][1]
    download_url = URLdecode(path_and_url[[1]][2])
    destination_path = file.path(KAGGLE_INPUT_PATH, directory)
    temp = tempfile(fileext = '.zip')
    download.file(download_url, temp)
    unzip(temp, overwrite = TRUE, exdir = destination_path)
    unlink(temp)
    print(paste0('Downloaded and unzipped: ', directory))
}

# %%
# This R environment comes with many helpful analytics packages installed
# It is defined by the kaggle/rstats Docker image: https://github.com/kaggle/docker-rstats
# For example, here's a helpful package to load

library(tidyverse) # metapackage of all tidyverse packages

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

list.files(path = "../input")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# [1] "eurusdforextradingindicatornotcleaned"
# [2] "eurusdtradingindicators"

# %%
library(parallel)
detectCores()
# Out:
# [1] 8

# %%
ptm <- proc.time()
#df <-read.csv('../input/eurusdforextradingindicatornotcleaned/combined-csv-files.csv', colClasses=c('integer', 'factor', rep('numeric', 42)))
df <-read.csv('../input/eurusdforextradingindicatornotcleaned/combined-csv-files.csv')
proc.time() - ptm
r<-df
# Out:
#    user  system elapsed
# 165.212   9.656 174.952

# %%
dim(r)
dataSetSize<-floor(dim(r)[1]/25)#
seqRrows<-rep.int(dataSetSize, 25)*c(seq (1,25))
seqRrows[25]=seqRrows[25]+21
# Out:
# [1] 3168471      44
# [1] 253476

# %%
a<-NA
for(BillCliton in 0:24){
    df<-r[((BillCliton*126738)+1):(seqRrows[BillCliton+1]-1),]
        

    
    }

# %%
dim(df)
# Out:
# [1] 126738     44

# %%
gggBoxer<-NA
for(BillCliton in 0:24){
    df<-r[((BillCliton*126738)+1):(seqRrows[BillCliton+1]-1),]
    
    

ptm <- proc.time()
df <- na.omit(df)
dim(df)
df<- unique(df)
dim(df)
names(df)
proc.time() - ptm
###########
##Vectorize to numericize or otherwise I lose data
df$Bid<-as.numeric(as.vector(df$Bid))
df$Ask<-as.numeric(as.vector(df$Ask))


df$BB.hi.SD4<-as.numeric(as.vector(df$BB.hi.SD4))
df$BB.LL.SD4<-as.numeric(as.vector(df$BB.LL.SD4))


df$BBUpHiSd4DifftoAsk=df$Ask-df$BB.hi.SD4
df$BBLowLowSd4Diff=df$Ask-df$BB.LL.SD4




ptm <- proc.time()
new<-c()
for(i in 1:((dim(df)[1]))){
  new[i]=df$Bid[i+60]-df$Ask[i]
}
df$profitIn60Ticks = new
proc.time() - ptm

#############Make an average price change over past 50 ticks
ptm <- proc.time()
newer<-matrix(, nrow = dim(df)[1], ncol =  5)
for(i in 251:dim(df)[1]){
  total=0
  for(j in (i-50): i){
    total=total+(df$Ask[j+1]-df$Ask[j])  
  }
  newer[i,1]=total/50
  total=0
  for(j in (i-100): (i-51)){
    total=total+(df$Ask[j+1]-df$Ask[j])  
  }
  newer[i,2]=total/50
  total=0
  for(j in (i-150): (i-101)){
    total=total+(df$Ask[j+1]-df$Ask[j])  
  }
  newer[i,3]=total/50
  total=0
  for(j in (i-200): (i-151)){
    total=total+(df$Ask[j+1]-df$Ask[j])  
  }
  newer[i,4]=total/50
  total=0
  for(j in (i-250): (i-201)){
    total=total+(df$Ask[j+1]-df$Ask[j])  
  }
  newer[i,5]=total/50
}

df$Last1MinProft<-newer[,1]
df$Last2MinProft<-newer[,2]
df$Last3MinProft<-newer[,3]
df$Last4MinProft<-newer[,4]
df$Last5MinProft<-newer[,5]

proc.time() - ptm

summary(newer)

##############################
#Creating a 9 lag variables, computationally very expensive
##############################

df$Bollinger.Upper.Hi.SD2<-as.numeric(as.vector(df$Bollinger.Upper.Hi.SD2))
df$BBUpHiSd2=ifelse(df$Bollinger.Upper.Hi.SD2<df$Ask,1,0)

df$Bollinger.Upper.Hi.SD2.5<-as.numeric(as.vector(df$Bollinger.Upper.Hi.SD2.5))
df$BBUpHiSd2_5=ifelse(df$Bollinger.Upper.Hi.SD2.5<df$Ask,1,0)

df$BB.hi.SD3<-as.numeric(as.vector(df$BB.hi.SD3))
df$BBUpHiSd3=ifelse(df$BB.hi.SD3<df$Ask,1,0)


df$BBUpHiSd4=ifelse(df$BB.hi.SD4<df$Ask,1,0)

df$BB.hi.SD4.5<-as.numeric(as.vector(df$BB.hi.SD4.5))
df$BBUpHiSd4_5=ifelse(df$BB.hi.SD4.5<df$Ask,1,0)
###Low Bands Low average Bands

df$Bollinger.lower.on.Low.SD2<-as.numeric(as.vector(df$Bollinger.lower.on.Low.SD2))
df$BBLowLowSd2=ifelse(df$Bollinger.lower.on.Low.SD2>df$Ask,1,0)

df$Bollinger.lower.on.Low.SD2.5<-as.numeric(as.vector(df$Bollinger.lower.on.Low.SD2.5))
df$BBLowLowSd2_5=ifelse(df$Bollinger.lower.on.Low.SD2.5>df$Ask,1,0)

df$BB.LowLow.SD3<-as.numeric(as.vector(df$BB.LowLow.SD3))
df$BBLowLowSd3=ifelse(df$BB.LowLow.SD3>df$Ask,1,0)


df$BBLowLowSd4=ifelse(df$BB.LL.SD4>df$Ask,1,0)

df$BB.LL.SD4.5<-as.numeric(as.vector(df$BB.LL.SD4.5))
df$BBLowLowSd4_5=ifelse(df$BB.LL.SD4.5>df$Ask,1,0)


##################################################################



ptm <- proc.time()
createLagVariablesNumeric<-function(dfDollarSign){
  newer<-matrix(, nrow = dim(df)[1], ncol =  9)
  print("Hello")
  for(i in 451:dim(df)[1]){
    total=0
    for(j in (i-50): i){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,1]=total/50
    total=0
    for(j in (i-100): (i-51)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,2]=total/50
    total=0
    for(j in (i-150): (i-101)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,3]=total/50
    total=0
    for(j in (i-200): (i-151)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,4]=total/50
    total=0
    for(j in (i-250): (i-201)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,5]=total/50
    total=0
    for(j in (i-300): (i-251)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,6]=total/50
    total=0
    for(j in (i-350): (i-301)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,7]=total/50
    total=0
    for(j in (i-400): (i-351)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,8]=total/50
    total=0
    for(j in (i-450): (i-401)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,9]=total/50
  }
  return(newer)
df$Bollinger.lower.on.Low.SD2Lag2min<-attmept1[,2]
df$Bollinger.lower.on.Low.SD2Lag3min<-attmept1[,3]
df$Bollinger.lower.on.Low.SD2Lag4min<-attmept1[,4]
df$Bollinger.lower.on.Low.SD2Lag5min<-attmept1[,5]
df$Bollinger.lower.on.Low.SD2Lag6min<-attmept1[,6]
df$Bollinger.lower.on.Low.SD2Lag7min<-attmept1[,7]
df$Bollinger.lower.on.Low.SD2Lag8min<-attmept1[,8]
df$Bollinger.lower.on.Low.SD2Lag9min<-attmept1[,9]



######################################################
df$momentumIndicator<-as.numeric(as.vector(df$momentumIndicator))
attmept1<-createLagVariablesNumeric(df$momentumIndicator)
df$momentumIndicatorLag1min<-attmept1[,1]
df$momentumIndicatorLag2min<-attmept1[,2]
df$momentumIndicatorLag3min<-attmept1[,3]
df$momentumIndicatorLag4min<-attmept1[,4]
df$momentumIndicatorLag5min<-attmept1[,5]
df$momentumIndicatorLag6min<-attmept1[,6]
df$momentumIndicatorLag7min<-attmept1[,7]
df$momentumIndicatorLag8min<-attmept1[,8]
df$momentumIndicatorLag9min<-attmept1[,9]
######################################################
df$MacDMain<-as.numeric(as.vector(df$MacDMain))
attmept1<-createLagVariablesNumeric(df$MacDMain)
df$MacDMainLag1min<-attmept1[,1]
df$MacDMainLag2min<-attmept1[,2]
df$MacDMainLag3min<-attmept1[,3]
df$MacDMainLag4min<-attmept1[,4]
df$MacDMainLag5min<-attmept1[,5]
df$MacDMainLag6min<-attmept1[,6]
df$MacDMainLag7min<-attmept1[,7]
df$MacDMainLag8min<-attmept1[,8]
df$MacDMainLag9min<-attmept1[,9]
######################################################
df$MacDSignal<-as.numeric(as.vector(df$MacDSignal))


attmept1<-createLagVariablesNumeric(df$MacDSignal)
df$MacDSignalLag1min<-attmept1[,1]
df$MacDSignalLag2min<-attmept1[,2]
df$MacDSignalLag3min<-attmept1[,3]
df$MacDSignalLag4min<-attmept1[,4]
df$MacDSignalLag5min<-attmept1[,5]
df$MacDSignalLag6min<-attmept1[,6]
df$MacDSignalLag7min<-attmept1[,7]
df$MacDSignalLag8min<-attmept1[,8]
df$MacDSignalLag9min<-attmept1[,9]
######################################################
df$MACD.diff.HistogramValue<-as.numeric(as.vector(df$MACD.diff.HistogramValue))


attmept1<-createLagVariablesNumeric(df$MACD.diff.HistogramValue)
df$MACD.diff.HistogramValueLag1min<-attmept1[,1]
df$MACD.diff.HistogramValueLag2min<-attmept1[,2]
df$MACD.diff.HistogramValueLag3min<-attmept1[,3]
df$MACD.diff.HistogramValueLag4min<-attmept1[,4]
df$MACD.diff.HistogramValueLag5min<-attmept1[,5]
df$MACD.diff.HistogramValueLag6min<-attmept1[,6]
df$MACD.diff.HistogramValueLag7min<-attmept1[,7]
df$MACD.diff.HistogramValueLag8min<-attmept1[,8]
df$MACD.diff.HistogramValueLag9min<-attmept1[,9]
######################################################
df$stochasticArr_Fast_Main<-as.numeric(as.vector(df$stochasticArr_Fast_Main))


attmept1<-createLagVariablesNumeric(df$stochasticArr_Fast_Main)
df$stochasticArr_Fast_MainLag1min<-attmept1[,1]
df$stochasticArr_Fast_MainLag2min<-attmept1[,2]
df$stochasticArr_Fast_MainLag3min<-attmept1[,3]
df$stochasticArr_Fast_MainLag4min<-attmept1[,4]
df$stochasticArr_Fast_MainLag5min<-attmept1[,5]
df$stochasticArr_Fast_MainLag6min<-attmept1[,6]
df$stochasticArr_Fast_MainLag7min<-attmept1[,7]
df$stochasticArr_Fast_MainLag8min<-attmept1[,8]
df$stochasticArr_Fast_MainLag9min<-attmept1[,9]
######################################################
df$stochasticArr_Fast_Signal<-as.numeric(as.vector(df$stochasticArr_Fast_Signal))


attmept1<-createLagVariablesNumeric(df$stochasticArr_Fast_Signal)
df$stochasticArr_Fast_SignalLag1min<-attmept1[,1]
df$stochasticArr_Fast_SignalLag2min<-attmept1[,2]
df$stochasticArr_Fast_SignalLag3min<-attmept1[,3]
df$stochasticArr_Fast_SignalLag4min<-attmept1[,4]
df$stochasticArr_Fast_SignalLag5min<-attmept1[,5]
df$stochasticArr_Fast_SignalLag6min<-attmept1[,6]
df$stochasticArr_Fast_SignalLag7min<-attmept1[,7]
df$stochasticArr_Fast_SignalLag8min<-attmept1[,8]
df$stochasticArr_Fast_SignalLag9min<-attmept1[,9]
######################################################
df$stochasticArr_Slow_Main<-as.numeric(as.vector(df$stochasticArr_Slow_Main))


attmept1<-createLagVariablesNumeric(df$stochasticArr_Slow_Main)
df$stochasticArr_Slow_MainLag1min<-attmept1[,1]
df$stochasticArr_Slow_MainLag2min<-attmept1[,2]
df$stochasticArr_Slow_MainLag3min<-attmept1[,3]
df$stochasticArr_Slow_MainLag4min<-attmept1[,4]
df$stochasticArr_Slow_MainLag5min<-attmept1[,5]
df$stochasticArr_Slow_MainLag6min<-attmept1[,6]
df$stochasticArr_Slow_MainLag7min<-attmept1[,7]
df$stochasticArr_Slow_MainLag8min<-attmept1[,8]
df$stochasticArr_Slow_MainLag9min<-attmept1[,9]
######################################################
df$stochasticArr_Slow_Signal<-as.numeric(as.vector(df$stochasticArr_Slow_Signal))



attmept1<-createLagVariablesNumeric(df$stochasticArr_Slow_Signal)
df$stochasticArr_Slow_SignalLag1min<-attmept1[,1]
df$stochasticArr_Slow_SignalLag2min<-attmept1[,2]
df$stochasticArr_Slow_SignalLag3min<-attmept1[,3]
df$stochasticArr_Slow_SignalLag4min<-attmept1[,4]
df$stochasticArr_Slow_SignalLag5min<-attmept1[,5]
df$stochasticArr_Slow_SignalLag6min<-attmept1[,6]
df$stochasticArr_Slow_SignalLag7min<-attmept1[,7]
df$stochasticArr_Slow_SignalLag8min<-attmept1[,8]
df$stochasticArr_Slow_SignalLag9min<-attmept1[,9]
######################################################
df$standDeviationPriceValueMedium<-as.numeric(as.vector(df$standDeviationPriceValueMedium))



attmept1<-createLagVariablesNumeric(df$standDeviationPriceValueMedium)
df$standDeviationPriceValueMediumLag1min<-attmept1[,1]
df$standDeviationPriceValueMediumLag2min<-attmept1[,2]
df$standDeviationPriceValueMediumLag3min<-attmept1[,3]
df$standDeviationPriceValueMediumLag4min<-attmept1[,4]
df$standDeviationPriceValueMediumLag5min<-attmept1[,5]
df$standDeviationPriceValueMediumLag6min<-attmept1[,6]
df$standDeviationPriceValueMediumLag7min<-attmept1[,7]
df$standDeviationPriceValueMediumLag8min<-attmept1[,8]
df$standDeviationPriceValueMediumLag9min<-attmept1[,9]
######################################################
df$Alligator.JawCurChart<-as.numeric(as.vector(df$Alligator.JawCurChart))


attmept1<-createLagVariablesNumeric(df$Alligator.JawCurChart)
df$Alligator.Teeth5minLag8min<-attmept1[,8]
df$Alligator.Teeth5minLag9min<-attmept1[,9]
######################################################
######################################################
df$Alligator.Lips5min<-as.numeric(as.vector(df$Alligator.Lips5min))

attmept1<-createLagVariablesNumeric(df$Alligator.Lips5min)
df$Alligator.Lips5minLag1min<-attmept1[,1]
df$Alligator.Lips5minLag2min<-attmept1[,2]
df$Alligator.Lips5minLag3min<-attmept1[,3]
df$Alligator.Lips5minLag4min<-attmept1[,4]
df$Alligator.Lips5minLag5min<-attmept1[,5]
df$Alligator.Lips5minLag6min<-attmept1[,6]
df$Alligator.Lips5minLag7min<-attmept1[,7]
df$Alligator.Lips5minLag8min<-attmept1[,8]
df$Alligator.Lips5minLag9min<-attmept1[,9]
######################################################
df$rsi.Price_Close.<-as.numeric(as.vector(df$rsi.Price_Close.))

attmept1<-createLagVariablesNumeric(df$rsi.Price_Close.)
df$rsi.Price_Close.Lag1min<-attmept1[,1]
df$rsi.Price_Close.Lag2min<-attmept1[,2]
df$rsi.Price_Close.Lag3min<-attmept1[,3]
df$rsi.Price_Close.Lag4min<-attmept1[,4]
df$rsi.Price_Close.Lag5min<-attmept1[,5]
df$rsi.Price_Close.Lag6min<-attmept1[,6]
df$rsi.Price_Close.Lag7min<-attmept1[,7]
df$rsi.Price_Close.Lag8min<-attmept1[,8]
df$rsi.Price_Close.Lag9min<-attmept1[,9]
#####################################################
#Creating an average of categorical
#########################################################
createLagVariablesCategorical<-function(dfDollarSign){
  newer<-matrix(, nrow = length(dfDollarSign), ncol =  9)
  print("Hello")
  for(i in 451:length(dfDollarSign)){
    total=0
    for(j in (i-50): i){
      total=total+(dfDollarSign[j])  
    }
    newer[i, 1]=total/50
    total=0
    for(j in (i-100): (i-51)){
      total=total+(dfDollarSign[j])  
    }
    newer[i, 2]=total/50
    total=0
    for(j in (i-150): (i-101)){
      total=total+(dfDollarSign[j])  
    }
    newer[i, 3]=total/50
    total=0
    for(j in (i-200): (i-151)){
      total=total+(dfDollarSign[j])  
    }
    newer[i, 4]=total/50
    total=0
    for(j in (i-250): (i-201)){
      total=total+(dfDollarSign[j])  
    }
    newer[i, 5]=total/50
    total=0
    for(j in (i-300): (i-251)){
      total=total+(dfDollarSign[j])  
    }
    newer[i, 6]=total/50
    total=0
    for(j in (i-350): (i-301)){
      total=total+(dfDollarSign[j])  
    }
    newer[i,7]=total/50
    total=0
    for(j in (i-400): (i-351)){
      total=total+(dfDollarSign[j])  
    }
    newer[i,8]=total/50
    total=0
    for(j in (i-450): (i-401)){
      total=total+(dfDollarSign[j])  
    }
    newer[i,9]=total/50
  }
  return(newer)
}


cheese <- createLagVariablesCategorical(df$BBUpHiSd3)
df$BBUpHiSd3CatLag1min<-cheese[,1]
df$BBUpHiSd3CatLag2min<-cheese[,2]
df$BBUpHiSd3CatLag3min<-cheese[,3]
df$BBUpHiSd3CatLag4min<-cheese[,4]
df$BBUpHiSd3CatLag5min<-cheese[,5]
df$BBUpHiSd3CatLag6min<-cheese[,6]
df$BBUpHiSd3CatLag7min<-cheese[,7]
df$BBUpHiSd3CatLag8min<-cheese[,8]
df$BBUpHiSd3CatLag9min<-cheese[,9]
################################################
##########################################################
cheese <- createLagVariablesCategorical(df$BBLowLowSd2)
df$BBLowLowSd2CatLag1min<-cheese[,1]
df$BBLowLowSd2CatLag2min<-cheese[,2]
df$BBLowLowSd2CatLag3min<-cheese[,3]
df$BBLowLowSd2CatLag4min<-cheese[,4]
df$BBLowLowSd2CatLag5min<-cheese[,5]
df$BBLowLowSd2CatLag6min<-cheese[,6]
df$BBLowLowSd2CatLag7min<-cheese[,7]
df$BBLowLowSd2CatLag8min<-cheese[,8]
df$BBLowLowSd2CatLag9min<-cheese[,9]

#########################################################
cheese <- createLagVariablesCategorical(df$BBLowLowSd3)
df$BBLowLowSd3CatLag1min<-cheese[,1]
df$BBLowLowSd3CatLag2min<-cheese[,2]
df$BBLowLowSd3CatLag3min<-cheese[,3]
df$BBLowLowSd3CatLag4min<-cheese[,4]
df$BBLowLowSd3CatLag5min<-cheese[,5]
df$BBLowLowSd3CatLag6min<-cheese[,6]
df$BBLowLowSd3CatLag7min<-cheese[,7]
df$BBLowLowSd3CatLag8min<-cheese[,8]
df$BBLowLowSd3CatLag9min<-cheese[,9]

#########################################################
cheese <- createLagVariablesCategorical(df$BBUpHiSd4)
df$BBUpHiSd4CatLag1min<-cheese[,1]
df$BBUpHiSd4CatLag2min<-cheese[,2]
df$BBUpHiSd4CatLag3min<-cheese[,3]
df$BBUpHiSd4CatLag4min<-cheese[,4]
df$BBUpHiSd4CatLag5min<-cheese[,5]
df$BBUpHiSd4CatLag6min<-cheese[,6]
df$BBUpHiSd4CatLag7min<-cheese[,7]
df$BBUpHiSd4CatLag8min<-cheese[,8]
df$BBUpHiSd4CatLag9min<-cheese[,9]

###########################################################
cheese <- createLagVariablesCategorical(df$BBUpHiSd2_5)
df$BBUpHiSd2_5CatLag1min<-cheese[,1]
df$BBUpHiSd2_5CatLag2min<-cheese[,2]
df$BBUpHiSd2_5CatLag3min<-cheese[,3]
df$BBUpHiSd2_5CatLag4min<-cheese[,4]
df$BBUpHiSd2_5CatLag5min<-cheese[,5]
df$BBUpHiSd2_5CatLag6min<-cheese[,6]
df$BBUpHiSd2_5CatLag7min<-cheese[,7]
df$BBUpHiSd2_5CatLag8min<-cheese[,8]
df$BBUpHiSd2_5CatLag9min<-cheese[,9]

###########################################################

###Dropping first ____ rows used to create lag features above 
df <- na.omit(df)


###################################################################
#Creating Response Variables
#####################################################################
#Make profit in 60 categorical
#Also make sure it is a large profit
#Note 8 is commisons. so break even is profit of 8
df$profit15In60TicksClassPlus=ifelse(df$profitIn60Ticks>0.00015,1,0)
df$profit20In60TicksClassPlus=ifelse(df$profitIn60Ticks>0.00020,1,0)
df$profit30In60TicksClassPlus=ifelse(df$profitIn60Ticks>0.00030,1,0)


df$profit15In60TicksClassMinus=ifelse(df$profitIn60Ticks<(-0.00015),1,0)
df$profit20In60TicksClassMinus=ifelse(df$profitIn60Ticks<(-0.00020),1,0)
df$profit30In60TicksClassMins=ifelse(df$profitIn60Ticks<(-0.00030),1,0)


df$profitAnyIn60TicksClass=ifelse(df$profitIn60Ticks>0.00000,1,0)
df$profitBreakEvenIn60TicksClass=ifelse(df$profitIn60Ticks>0.00008,1,0)


#Large Price change
df$priceChange20In60TicksClass=ifelse(abs(df$profitIn60Ticks)>0.00020,1,0)
df$priceChange25In60TicksClass=ifelse(abs(df$profitIn60Ticks)>0.00025,1,0)
df$priceChange30In60TicksClass=ifelse(abs(df$profitIn60Ticks)>0.00030,1,0)



dim(df)
proc.time() - ptm
write.csv(x=df, file=paste("tadingIndicatorsCleaned_the",BillCliton, sep = "_"))
#Need to appened specific dataframes or write specifc subsets 
gggBoxer <- rbind(gggBoxer, subset(df,priceChange20In60TicksClass==1))
}

write.csv(x=gggBoxer, file="tadingIndicatorsCleanedOnly20ChangeHighClass")
# Out:
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# ...

# %%
write.csv(x=df, file="tadingIndicatorsCleaned24th")

# %%
class()
# Out:
# [1] "character"

# %%
first25th<-df

# %%
createLagVariablesCategorical<-function(dfDollarSign){
  newer<-matrix(, nrow = length(dfDollarSign), ncol =  9)
  print("Hello")
  for(i in 451:length(dfDollarSign)){
    total=0
    for(j in (i-50): i){
      total=total+(dfDollarSign[j])  
    }
    newer[i, 1]=total/50
    total=0
    for(j in (i-100): (i-51)){
      total=total+(dfDollarSign[j])  
    }
    newer[i, 2]=total/50
    total=0
    for(j in (i-150): (i-101)){
      total=total+(dfDollarSign[j])  
    }
    newer[i, 3]=total/50
    total=0
    for(j in (i-200): (i-151)){
      total=total+(dfDollarSign[j])  
    }
    newer[i, 4]=total/50
    total=0
    for(j in (i-250): (i-201)){
      total=total+(dfDollarSign[j])  
    }
    newer[i, 5]=total/50
    total=0
    for(j in (i-300): (i-251)){
      total=total+(dfDollarSign[j])  
    }
    newer[i, 6]=total/50
    total=0
    for(j in (i-350): (i-301)){
      total=total+(dfDollarSign[j])  
    }
    newer[i,7]=total/50
    total=0
    for(j in (i-400): (i-351)){
      total=total+(dfDollarSign[j])  
    }
    newer[i,8]=total/50
    total=0
    for(j in (i-450): (i-401)){
      total=total+(dfDollarSign[j])  
    }
    newer[i,9]=total/50
  }
  return(newer)
rd Qu.:0.0000   3rd Qu.:0.0000   3rd Qu.:0.0000   3rd Qu.:0.0000
# ...

# %%
summary(df)
# Out:
#        X                        Timestamp                      Open
#  Min.   :   450   2020.09.29 06:00:02:     5   1.17388           :   734
#  1st Qu.: 26726   2020.09.29 06:00:07:     5   1.17375           :   644
#  Median : 53002   2020.09.29 06:00:22:     5   1.17369           :   640
#  Mean   : 53002   2020.09.29 06:08:08:     5   1.1739600000000001:   632
#  3rd Qu.: 79278   2020.09.29 06:09:04:     5   1.17371           :   602
#  Max.   :105554   2020.09.29 06:10:57:     5   1.17336           :   572
#                   (Other)            :105075   (Other)           :101281
#                 Close             Ask             Bid
#  1.17299           :   369   Min.   :1.167   Min.   :1.167
#  1.17361           :   356   1st Qu.:1.170   1st Qu.:1.170
#  1.1729399999999999:   349   Median :1.172   Median :1.172
#  1.173             :   347   Mean   :1.172   Mean   :1.172
#  1.17298           :   340   3rd Qu.:1.174   3rd Qu.:1.174
# ...

# %%
df$BBUpHiSd2=ifelse(df$Bollinger.Upper.Hi.SD2<df$Ask,1,0)
df$BBUpHiSd2_5=ifelse(df$Bollinger.Upper.Hi.SD2.5<df$Ask,1,0)
df$BBUpHiSd3=ifelse(df$BB.hi.SD3<df$Ask,1,0)
df$BBUpHiSd4=ifelse(df$BB.hi.SD4<df$Ask,1,0)
df$BBUpHiSd4_5=ifelse(df$BB.hi.SD4.5<df$Ask,1,0)
###Low Bands Low average Bands
df$BBLowLowSd2=ifelse(df$Bollinger.lower.on.Low.SD2>df$Ask,1,0)
df$BBLowLowSd2_5=ifelse(df$Bollinger.lower.on.Low.SD2.5>df$Ask,1,0)
df$BBLowLowSd3=ifelse(df$BB.LowLow.SD3>df$Ask,1,0)
df$BBLowLowSd4=ifelse(df$BB.LL.SD4>df$Ask,1,0)


df$BBLowLowSd4_5=ifelse(df$BB.LL.SD4.5>df$Ask,1,0)

# %%
 lapply(1:((dim(df)[1], getPrimeNumbers(prime))
           
           
library(doParallel)  
no_cores <- detectCores() - 1  
cl <- makeCluster(no_cores, type="FORK")  
registerDoParallel(cl)  
result <- foreach(i=10:10000) %dopar% getPrimeNumbers(i)

# %%
# Out:
#    user  system elapsed
#   0.360   0.004   0.362

# %%
# Out:
#    user  system elapsed
#  98.736   0.000  98.751
#        V1               V2               V3               V4
#  Min.   :-1e-05   Min.   :-1e-05   Min.   :-1e-05   Min.   :-1e-05
#  1st Qu.: 0e+00   1st Qu.: 0e+00   1st Qu.: 0e+00   1st Qu.: 0e+00
#  Median : 0e+00   Median : 0e+00   Median : 0e+00   Median : 0e+00
#  Mean   : 0e+00   Mean   : 0e+00   Mean   : 0e+00   Mean   : 0e+00
#  3rd Qu.: 0e+00   3rd Qu.: 0e+00   3rd Qu.: 0e+00   3rd Qu.: 0e+00
#  Max.   : 2e-05   Max.   : 2e-05   Max.   : 2e-05   Max.   : 2e-05
#  NA's   :251      NA's   :250      NA's   :250      NA's   :250
#        V5
#  Min.   :-1e-05
#  1st Qu.: 0e+00
#  Median : 0e+00
#  Mean   : 0e+00
#  3rd Qu.: 0e+00
#  Max.   : 2e-05
#  NA's   :250

# %%
ptm <- proc.time()
createLagVariablesNumeric<-function(dfDollarSign){
  newer<-matrix(, nrow = dim(df)[1], ncol =  9)
  print("Hello")
  for(i in 451:dim(df)[1]){
    total=0
    for(j in (i-50): i){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,1]=total/50
    total=0
    for(j in (i-100): (i-51)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,2]=total/50
    total=0
    for(j in (i-150): (i-101)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,3]=total/50
    total=0
    for(j in (i-200): (i-151)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,4]=total/50
    total=0
    for(j in (i-250): (i-201)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,5]=total/50
    total=0
    for(j in (i-300): (i-251)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,6]=total/50
    total=0
    for(j in (i-350): (i-301)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,7]=total/50
    total=0
    for(j in (i-400): (i-351)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,8]=total/50
    total=0
    for(j in (i-450): (i-401)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,9]=total/50
  }
  return(newer)
df$MacDMainLag5min<-attmept1[,5]
df$MacDMainLag6min<-attmept1[,6]
df$MacDMainLag7min<-attmept1[,7]
df$MacDMainLag8min<-attmept1[,8]
df$MacDMainLag9min<-attmept1[,9]
######################################################
df$MacDSignal<-as.numeric(as.vector(df$MacDSignal))


attmept1<-createLagVariablesNumeric(df$MacDSignal)
df$MacDSignalLag1min<-attmept1[,1]
df$MacDSignalLag2min<-attmept1[,2]
df$MacDSignalLag3min<-attmept1[,3]
df$MacDSignalLag4min<-attmept1[,4]
df$MacDSignalLag5min<-attmept1[,5]
df$MacDSignalLag6min<-attmept1[,6]
df$MacDSignalLag7min<-attmept1[,7]
df$MacDSignalLag8min<-attmept1[,8]
df$MacDSignalLag9min<-attmept1[,9]
######################################################
df$MACD.diff.HistogramValue<-as.numeric(as.vector(df$MACD.diff.HistogramValue))


attmept1<-createLagVariablesNumeric(df$MACD.diff.HistogramValue)
df$MACD.diff.HistogramValueLag1min<-attmept1[,1]
df$MACD.diff.HistogramValueLag2min<-attmept1[,2]
df$MACD.diff.HistogramValueLag3min<-attmept1[,3]
df$MACD.diff.HistogramValueLag4min<-attmept1[,4]
df$MACD.diff.HistogramValueLag5min<-attmept1[,5]
df$MACD.diff.HistogramValueLag6min<-attmept1[,6]
df$MACD.diff.HistogramValueLag7min<-attmept1[,7]
df$MACD.diff.HistogramValueLag8min<-attmept1[,8]
df$MACD.diff.HistogramValueLag9min<-attmept1[,9]
######################################################
df$stochasticArr_Fast_Main<-as.numeric(as.vector(df$stochasticArr_Fast_Main))


attmept1<-createLagVariablesNumeric(df$stochasticArr_Fast_Main)
df$stochasticArr_Fast_MainLag1min<-attmept1[,1]
df$stochasticArr_Fast_MainLag2min<-attmept1[,2]
df$stochasticArr_Fast_MainLag3min<-attmept1[,3]
df$stochasticArr_Fast_MainLag4min<-attmept1[,4]
df$stochasticArr_Fast_MainLag5min<-attmept1[,5]
df$stochasticArr_Fast_MainLag6min<-attmept1[,6]
df$stochasticArr_Fast_MainLag7min<-attmept1[,7]
df$stochasticArr_Fast_MainLag8min<-attmept1[,8]
df$stochasticArr_Fast_MainLag9min<-attmept1[,9]
######################################################
df$stochasticArr_Fast_Signal<-as.numeric(as.vector(df$stochasticArr_Fast_Signal))


attmept1<-createLagVariablesNumeric(df$stochasticArr_Fast_Signal)
df$stochasticArr_Fast_SignalLag1min<-attmept1[,1]
df$stochasticArr_Fast_SignalLag2min<-attmept1[,2]
df$stochasticArr_Fast_SignalLag3min<-attmept1[,3]
df$stochasticArr_Fast_SignalLag4min<-attmept1[,4]
df$stochasticArr_Fast_SignalLag5min<-attmept1[,5]
df$stochasticArr_Fast_SignalLag6min<-attmept1[,6]
df$stochasticArr_Fast_SignalLag7min<-attmept1[,7]
df$stochasticArr_Fast_SignalLag8min<-attmept1[,8]
df$stochasticArr_Fast_SignalLag9min<-attmept1[,9]
######################################################
<-as.numeric(as.vector(df$MacDMain))


attmept1<-createLagVariablesNumeric(df$stochasticArr_Slow_Main)
df$stochasticArr_Slow_MainLag1min<-attmept1[,1]
df$stochasticArr_Slow_MainLag2min<-attmept1[,2]
df$stochasticArr_Slow_MainLag3min<-attmept1[,3]
df$stochasticArr_Slow_MainLag4min<-attmept1[,4]
attmept1<-createLagVariablesNumeric(df$Alligator.LipsCurChart)
df$Alligator.LipsCurChartLag1min<-attmept1[,1]
df$Alligator.LipsCurChartLag2min<-attmept1[,2]
df$Alligator.LipsCurChartLag3min<-attmept1[,3]
df$Alligator.LipsCurChartLag4min<-attmept1[,4]
df$Alligator.LipsCurChartLag5min<-attmept1[,5]
df$Alligator.LipsCurChartLag6min<-attmept1[,6]
df$Alligator.LipsCurChartLag7min<-attmept1[,7]
df$Alligator.LipsCurChartLag8min<-attmept1[,8]
df$Alligator.LipsCurChartLag9min<-attmept1[,9]








###########################################################
###Dropping first ____ rows used to create lag features above 
df <- na.omit(df)

proc.time() - ptm
# Out:
# [1] "Hello"
#    user  system elapsed
#   5.860   0.004   5.860

# %%
summary(df$Money.Flow.INdexLag9min)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
# -0.7150 -0.0583 -0.0010  0.0000  0.0575  0.8697     450

# %%
# Out:
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"

# %%
summary(df$momentumIndicatorLag9min)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
# -0.0019 -0.0002  0.0000  0.0000  0.0002  0.0018     450

# %%
vecotrBig<-as.numeric(as.vector(df[['Bid']]))
vecotrAsk<-as.numeric(as.vector(df[['Ask']]))

# %%
summary(vecotrAsk)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#     1.2     1.2     1.2     1.2     1.2     1.2  350238

# %%
# Out:
# [1] -0.00016
# [1] -0.00128

# %%
      new[i]=(vecotrBig[i+60]-vecotrAsk[i])
# Out:
# [1] -1.16707

# %%
ptm <- proc.time()
new<-c()
for(i in 1:((dim(df)[1]))){
      new[i]=df$Buy[i+60]-df$Ask[i]
}
    df$profitIn60Ticks = new

dim(df)
summary(df$profitIn60Ticks)
proc.time() - ptm

# %%
class(df)
# Out:
# [1] "data.frame"

# %%
#head(df$profitIn60Ticks)
#60 values of old def are NA from creating proftitin60Ticks
#df <- na.omit(df)

ptm <- proc.time()
df$profitIn60Ticks20MoveClassBothDirct<-ifelse(df$profitIn60Ticks<(-0.00020), "BigDown",ifelse(df$profitIn60Ticks>0.00020,"BigUp","NoBig"))
proc.time() - ptm
dim(df)
# Out:
#    user  system elapsed
#   0.288   0.004   0.291
# [1] 1056156      46

# %%
table(df$profitIn60Ticks20MoveClassBothDirct)
# Out:
# BigDown   BigUp   NoBig
#   62178   27937  615743

# %%
#Below is an average, not a profit!!!!
#REVISE ANY CODE BASED ON THIS
#It is the average change per tick in the last 50 ticks
ptm <- proc.time()
newer<-matrix(, nrow = dim(df)[1], ncol =  5)
for(i in 251:dim(df)[1]){
  total=0
  for(j in (i-50): i){
    total=total+(vecotrAsk[j+1]-vecotrAsk[j])  
  }
  newer[i,1]=total/50
  total=0
  for(j in (i-100): (i-51)){
    total=total+(vecotrAsk[j+1]-vecotrAsk[j])  
  }
  newer[i,2]=total/50
  total=0
  for(j in (i-150): (i-101)){
    total=total+(vecotrAsk[j+1]-vecotrAsk[j])  
  }
  newer[i,3]=total/50
  total=0
  for(j in (i-200): (i-151)){
    total=total+(vecotrAsk[j+1]-vecotrAsk[j])  
  }
  newer[i,4]=total/50
  total=0
  for(j in (i-250): (i-201)){
    total=total+(vecotrAsk[j+1]-vecotrAsk[j])  
  }
  newer[i,5]=total/50
}

df$Last1MinProft<-newer[,1]
df$Last2MinProft<-newer[,2]
df$Last3MinProft<-newer[,3]
df$Last4MinProft<-newer[,4]
df$Last5MinProft<-newer[,5]
head(newer)
dim(df)
proc.time() - ptm
# Out:
#      [,1] [,2] [,3] [,4] [,5]
# [1,] NA   NA   NA   NA   NA
# [2,] NA   NA   NA   NA   NA
# [3,] NA   NA   NA   NA   NA
# [4,] NA   NA   NA   NA   NA
# [5,] NA   NA   NA   NA   NA
# [6,] NA   NA   NA   NA   NA
# [1] 1056156      51
#    user  system elapsed
#  28.236   0.016  28.254

# %%
0+(vecotrAsk[104]-vecotrAsk[100])
# Out:
# [1] -5e-05

# %%
tail(newer)
# Out:
#            [,1] [,2] [,3] [,4] [,5]
# [1056151,] NA   NA   NA   NA   NA
# [1056152,] NA   NA   NA   NA   NA
# [1056153,] NA   NA   NA   NA   NA
# [1056154,] NA   NA   NA   NA   NA
# [1056155,] NA   NA   NA   NA   NA
# [1056156,] NA   NA   NA   NA   NA

# %%
dfDollarSign<-as.numeric(as.vector(dfTake))

# %%
summary(df$Last5MinProft)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#       0       0       0       0       0       0  350288

# %%
#Function to make an average movement change over last 50 ticks

createLagVariablesNumeric<-function(dfTake){
  dfDollarSign<-as.numeric(as.vector(dfTake))
  newer<-matrix(, nrow = dim(df)[1], ncol =  9)
  print("Hello")
  for(i in 451:dim(df)[1]){
    total=0
    for(j in (i-50): i){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,1]=total/50
    total=0
    for(j in (i-100): (i-51)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,2]=total/50
    total=0
    for(j in (i-150): (i-101)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,3]=total/50
    total=0
    for(j in (i-200): (i-151)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,4]=total/50
    total=0
    for(j in (i-250): (i-201)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,5]=total/50
    total=0
    for(j in (i-300): (i-251)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,6]=total/50
    total=0
    for(j in (i-350): (i-301)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,7]=total/50
    total=0
    for(j in (i-400): (i-351)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,8]=total/50
    total=0
    for(j in (i-450): (i-401)){
      total=total+(dfDollarSign[j+1]-dfDollarSign[j])  
    }
    newer[i,9]=total/50
  }
  return(newer)
}

# %%
ptm <- proc.time()
attmept1<-createLagVariablesNumeric(df[['Money.Flow.INdex']])
df$Money.Flow.INdexLag1min<-attmept1[,1]
df$Money.Flow.INdexLag2min<-attmept1[,2]
df$Money.Flow.INdexLag3min<-attmept1[,3]
df$Money.Flow.INdexLag4min<-attmept1[,4]
df$Money.Flow.INdexLag5min<-attmept1[,5]
df$Money.Flow.INdexLag6min<-attmept1[,6]
df$Money.Flow.INdexLag7min<-attmept1[,7]
df$Money.Flow.INdexLag8min<-attmept1[,8]
df$Money.Flow.INdexLag9min<-attmept1[,9]

# %%
ptm <- proc.time()
attmept1<-createLagVariablesNumeric(df[['Money.Flow.INdex']])
df$Money.Flow.INdexLag1min<-attmept1[,1]
df$Money.Flow.INdexLag2min<-attmept1[,2]
df$Money.Flow.INdexLag3min<-attmept1[,3]
df$Money.Flow.INdexLag4min<-attmept1[,4]
df$Money.Flow.INdexLag5min<-attmept1[,5]
df$Money.Flow.INdexLag6min<-attmept1[,6]
df$Money.Flow.INdexLag7min<-attmept1[,7]
df$Money.Flow.INdexLag8min<-attmept1[,8]
df$Money.Flow.INdexLag9min<-attmept1[,9]
###################################################
attmept1<-createLagVariablesNumeric(df[['rsi.Price_Close.']])
df$rsi.Price_Close.Lag1min<-attmept1[,1]
df$rsi.Price_Close.Lag2min<-attmept1[,2]
df$rsi.Price_Close.Lag3min<-attmept1[,3]
df$rsi.Price_Close.Lag4min<-attmept1[,4]
df$rsi.Price_Close.Lag5min<-attmept1[,5]
df$rsi.Price_Close.Lag6min<-attmept1[,6]
df$rsi.Price_Close.Lag7min<-attmept1[,7]
df$rsi.Price_Close.Lag8min<-attmept1[,8]
df$rsi.Price_Close.Lag9min<-attmept1[,9]
df$Alligator.Lips5minLag4min<-attmept1[,4]
df$Alligator.Lips5minLag5min<-attmept1[,5]
df$Alligator.Lips5minLag6min<-attmept1[,6]
df$Alligator.Lips5minLag7min<-attmept1[,7]
df$Alligator.Lips5minLag8min<-attmept1[,8]
df$Alligator.Lips5minLag9min<-attmept1[,9]

#########################################################
attmept1<-createLagVariablesNumeric(df[['BB.hi.SD3']])
df$BB.hi.SD3Lag1min<-attmept1[,1]
df$BB.hi.SD3Lag2min<-attmept1[,2]
df$BB.hi.SD3Lag3min<-attmept1[,3]
df$BB.hi.SD3Lag4min<-attmept1[,4]
df$BB.hi.SD3Lag5min<-attmept1[,5]
df$BB.hi.SD3Lag6min<-attmept1[,6]
df$BB.hi.SD3Lag7min<-attmept1[,7]
df$BB.hi.SD3Lag8min<-attmept1[,8]
df$BB.hi.SD3Lag9min<-attmept1[,9]
#################
attmept1<-createLagVariablesNumeric(df[['Bollinger.Lower.MediumPrice.SD2']])
df$Bollinger.Lower.MediumPrice.SD2Lag1min<-attmept1[,1]
df$Bollinger.Lower.MediumPrice.SD2Lag2min<-attmept1[,2]
df$Bollinger.Lower.MediumPrice.SD2Lag3min<-attmept1[,3]
df$Bollinger.Lower.MediumPrice.SD2Lag4min<-attmept1[,4]
df$Bollinger.Lower.MediumPrice.SD2Lag5min<-attmept1[,5]
df$Bollinger.Lower.MediumPrice.SD2Lag6min<-attmept1[,6]
df$Bollinger.Lower.MediumPrice.SD2Lag7min<-attmept1[,7]
df$Bollinger.Lower.MediumPrice.SD2Lag8min<-attmept1[,8]
df$Bollinger.Lower.MediumPrice.SD2Lag9min<-attmept1[,9]
#################
attmept1<-createLagVariablesNumeric(df[['BB.LowLow.SD3']])
df$BB.LowLow.SD3Lag1min<-attmept1[,1]
df$BB.LowLow.SD3Lag2min<-attmept1[,2]
df$BB.LowLow.SD3Lag3min<-attmept1[,3]
df$BB.LowLow.SD3Lag4min<-attmept1[,4]
df$BB.LowLow.SD3Lag5min<-attmept1[,5]
df$BB.LowLow.SD3Lag6min<-attmept1[,6]
df$BB.LowLow.SD3Lag7min<-attmept1[,7]
df$BB.LowLow.SD3Lag8min<-attmept1[,8]
df$BB.LowLow.SD3Lag9min<-attmept1[,9]

proc.time() - ptm
dim(df)
summary(df)
# Out:
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
#     user   system  elapsed
# 1209.220    0.028 1209.465
# [1] 1056156     248
#        X
#  Min.   :      0
#  1st Qu.: 264039
#  Median : 528078
#  Mean   : 528078
#  3rd Qu.: 792116
#  Max.   :1056155
#
# ...

# %%
ptm <- proc.time()



proc.time() - ptm
# Out:
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
#    user  system elapsed
# 978.140   0.028 978.340

# %%
summary(df)
# Out:
#        X
#  Min.   :      0
#  1st Qu.: 264039
#  Median : 528078
#  Mean   : 528078
#  3rd Qu.: 792116
#  Max.   :1056155
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Timestamp
# ...

# %%
reef <- na.omit(df)
dim(reef)
# Out:
# [1] 1055646     249

# %%
head(df$Ask)
# Out:
# [1] 338 338 338 338 339 339

# %%
ptm <- proc.time()
###########################################################
###Dropping first ____ rows used to create lag features above 
df <- na.omit(df)
###########################################################
####Turning Boliger Band features into categorical
#names(df)
###Upper Bands high average Bands
df$Ask<-as.numeric(df$Ask)
df$Bollinger.Upper.Hi.SD2<-as.numeric(df$Bollinger.Upper.Hi.SD2)
df$BBUpHiSd2Cat=ifelse(df$Bollinger.Upper.Hi.SD2<df$Ask,1,0)

df$Bollinger.Upper.Hi.SD2.5<-as.numeric(df$Bollinger.Upper.Hi.SD2.5)
df$BBUpHiSd2_5Cat=ifelse(df$Bollinger.Upper.Hi.SD2.5<df$Ask,1,0)

df$BB.hi.SD3<-as.numeric(df$BB.hi.SD3)
df$BBUpHiSd3Cat=ifelse(df$BB.hi.SD3<df$Ask,1,0)

df$BB.hi.SD4<-as.numeric(df$BB.hi.SD4)
df$BBUpHiSd4Cat=ifelse(df$BB.hi.SD4<df$Ask,1,0)

df$BB.hi.SD4.5<-as.numeric(df$BB.hi.SD4.5)
df$BBUpHiSd4_5Cat=ifelse(df$BB.hi.SD4.5<df$Ask,1,0)


###Low Bands Low average Bands
df$Bollinger.lower.on.Low.SD2<-as.numeric(df$Bollinger.lower.on.Low.SD2)
df$BBLowLowSd2Cat=ifelse(df$Bollinger.lower.on.Low.SD2>df$Ask,1,0)


df$Bollinger.lower.on.Low.SD2.5<-as.numeric(df$Bollinger.lower.on.Low.SD2.5)
df$BBLowLowSd2_5Cat=ifelse(df$Bollinger.lower.on.Low.SD2.5>df$Ask,1,0)

df$BB.LowLow.SD3<- as.numeric(df$BB.LowLow.SD3)
df$BBLowLowSd3Cat=ifelse(df$BB.LowLow.SD3>df$Ask,1,0)

df$BB.LL.SD4<-as.numeric(df$BB.LL.SD4)
df$BBLowLowSd4Cat=ifelse(df$BB.LL.SD4>df$Ask,1,0)

df$BB.LL.SD4.5<-as.numeric(df$BB.LL.SD4.5)
df$BBLowLowSd4_5Cat=ifelse(df$BB.LL.SD4.5>df$Ask,1,0)
###
###########################################################
summary(df)
proc.time() - ptm
# Out:
#        X
#  Min.   :    450
#  1st Qu.: 264361
#  Median : 528272
#  Mean   : 528272
#  3rd Qu.: 792184
#  Max.   :1056095
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Timestamp
# ...

# %%
ptm <- proc.time()


proc.time() - ptm
# Out:
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
#    user  system elapsed
# 506.704   0.040 506.829

# %%
ptm <- proc.time()


proc.time() - ptm
# Out:
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
#    user  system elapsed
# 153.896   0.008 153.925

# %%
ptm <- proc.time()





proc.time() - ptm
# Out:
# [1] "Hello"
# [1] "Hello"
# [1] "Hello"
#    user  system elapsed
# 152.824   0.016 152.860

# %%
dim(df)[1]
length(as.numeric())
# Out:
#    user  system elapsed
#   0.032   0.000   0.032

# %%
createLagVariablesCategorical<-function(dfTake){
  
  dfDollarSign<-as.numeric(df[['BBUpHiSd2Cat']])
  newer<-matrix(, nrow = length(dfDollarSign), ncol =  9)
  print("Hello")
  for(i in 451:length(dfDollarSign)){
    total=0
    for(j in (i-50): i){
      if dfDollarSign[j] total=total+(dfDollarSign[j])  
    }
    newer[i, 1]=total/50
    total=0
    for(j in (i-100): (i-51)){
      total=total+(dfDollarSign[j])  
    }
    newer[i, 2]=total/50
    total=0
    for(j in (i-150): (i-101)){
      total=total+(dfDollarSign[j])  
    }
    newer[i, 3]=total/50
    total=0
    for(j in (i-200): (i-151)){
      total=total+(dfDollarSign[j])  
    }
    newer[i, 4]=total/50
    total=0
    for(j in (i-250): (i-201)){
      total=total+(dfDollarSign[j])  
    }
    newer[i,
df$BBLowLowSd2_5CatLag7min<-cheese[,7]
df$BBLowLowSd2_5CatLag8min<-cheese[,8]
df$BBLowLowSd2_5CatLag9min<-cheese[,9]

cheese <- createLagVariablesCategorical(df[['BBLowLowSd3Cat']])
df$BBLowLowSd3CatLag1min<-cheese[,1]
df$BBLowLowSd3CatLag2min<-cheese[,2]
df$BBLowLowSd3CatLag3min<-cheese[,3]
df$BBLowLowSd3CatLag4min<-cheese[,4]
df$BBLowLowSd3CatLag5min<-cheese[,5]
df$BBLowLowSd3CatLag6min<-cheese[,6]
df$BBLowLowSd3CatLag7min<-cheese[,7]
df$BBLowLowSd3CatLag8min<-cheese[,8]
df$BBLowLowSd3CatLag9min<-cheese[,9]

proc.time() - ptm
# Out:
# [1] 0
# [1]   0 264
# [1] "Hello"
# Error in `[<-`(`*tmp*`, i, 1, value = total/50): subscript out of bounds
# Traceback:
#
# 1. createLagVariablesCategorical(df[["BBUpHiSd2Cat"]])

# %%
PLEASE CHECK THIS OUT FOR LATER
http://uc-r.github.io/gbm_regression#:~:text=The%20gbm%20R%20package%20is,and%20Friedman's%20gradient%20boosting%20machine.&text=Stochastic%20GBM.,Supports%20Classification%20and%20regression%20trees.

https://www.kaggle.com/rowang/smote-for-imbalanced-dataset-notebook-r-caret

https://ilearn.sfsu.edu/ay2021/pluginfile.php/654339/mod_resource/content/1/Lab_ImbalancedClassification.R

Do RF for class imbalance

# %%
#Make newRSI
for(i in 1:(dim(df)[1])){
  if(df$rsi.Price_Close.[i] >=90){
    placeHold[i]=.6
  }else if( df$rsi.Price_Close.[i]<90 &&df$rsi.Price_Close.[i]>80 ){
    placeHold[i]=.28
  }else if( df$rsi.Price_Close.[i]<=80 &&df$rsi.Price_Close.[i]>70 ){
    placeHold[i]=.15
  }else if( df$rsi.Price_Close.[i]<=10 ){
    placeHold[i]=-.6
  }else if( df$rsi.Price_Close.[i]>10 &&df$rsi.Price_Close.[i]<20 ){
    placeHold[i]=-.28
  }else if( df$rsi.Price_Close.[i]>=20 &&df$rsi.Price_Close.[i]<30 ){
    placeHold[i]=-.15
  }else{
    placeHold[i]=0
  }
}

#table(placeHold)
#dim(df)
#length(placeHold)
df$reRSI<-placeHold

# %%
#Make profit in 60 categorical
#Also make sure it is a large profit
#Note 8 is commisons. so break even is profit of 8



df$profit15In60TicksClassPlus=ifelse(df$profitIn60Ticks>0.00015,1,0)
df$profit20In60TicksClassPlus=ifelse(df$profitIn60Ticks>0.00020,1,0)
df$profit30In60TicksClassPlus=ifelse(df$profitIn60Ticks>0.00030,1,0)


df$profit15In60TicksClassMinus=ifelse(df$profitIn60Ticks<(-0.00015),1,0)
df$profit20In60TicksClassMinus=ifelse(df$profitIn60Ticks<(-0.00020),1,0)
df$profit30In60TicksClassMins=ifelse(df$profitIn60Ticks<(-0.00030),1,0)

table(df$profit20In60TicksClassMinus)


df$profitAnyIn60TicksClass=ifelse(df$profitIn60Ticks>0.00000,1,0)
df$profitBreakEvenIn60TicksClass=ifelse(df$profitIn60Ticks>0.00008,1,0)


#Large Price change
df$priceChange20In60TicksClass=ifelse(abs(df$profitIn60Ticks)>0.00020,1,0)
df$priceChange25In60TicksClass=ifelse(abs(df$profitIn60Ticks)>0.00025,1,0)
df$priceChange30In60TicksClass=ifelse(abs(df$profitIn60Ticks)>0.00030,1,0)
